# %%
#Server Setup
# %cd /content
# %env TF_CPP_MIN_LOG_LEVEL=1
# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !apt install -qq libcairo2-dev pkg-config python3-dev
# !dpkg -i *.deb
# !rm *
# !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !pip install -q xformers==0.0.19 --no-deps -qq triton==2.0.0 -U

#Stable Diffusion Framework
# %cd /content
# !git clone https://github.com/RaannaKasturi/VILID
print("Stable Diffusion Framework Downloaded")

#@markdown Stable Diffusion Extensions
update_extensions = True #@param {type:"boolean"}
# %cd /content/VILID
# !wget -O /content/VILID/extensions/extensions.zip https://huggingface.co/raannakasturi/VILID-assets/resolve/main/extensions.zip
# %cd /content/VILID/extensions
# !unzip -o /content/VILID/extensions/extensions.zip
# !rm /content/VILID/extensions/extensions.zip
# %cd /content
if not update_extensions:
  print("Extensions Downloaded")
else:
  # %cd /content/VILID/extensions/VILID-adetailer
  # !git pull
  # %cd /content/VILID/extensions/VILID-animatediff
  # !git pull
  # %cd /content/VILID/extensions/VILID-aspect-ratio-helper
  # !git pull
  # %cd /content/VILID/extensions/VILID-batchlinks
  # !git pull
  # %cd /content/VILID/extensions/VILID-civitai
  # !git pull
  # %cd /content/VILID/extensions/VILID-controlnet
  # !git pull
  # %cd /content/VILID/extensions/VILID-deforum
  # !git pull
  # %cd /content/VILID/extensions/VILID-images-browser
  # !git pull
  # %cd /content/VILID/extensions/VILID-openpose-editor
  # !git pull
  # %cd /content/VILID/extensions/VILID-posex
  # !git pull
  # %cd /content/VILID/extensions/VILID-rembg
  # !git pull
  # %cd /content/VILID/extensions/VILID-roop
  # !git pull
  # %cd /content/VILID/extensions/VILID-steps-animation
  # !git pull
  # %cd /content/VILID/extensions/VILID-tagcomplete
  # !git pull
  # %cd /content/VILID/extensions/VILID-ultimate-upscale
  # !git pull
  # %cd /content
  print("Stable Diffusion Extensions Downloaded & Updated")

#@markdown Stable Diffusion Models
SD_Model = "ToonYou 6" # @param ["Dreamshaper v7", "ReV Animated v1.2.2", "Protogen x5.8 Rebuilt (Scifi+Anime) Official Release", "Realistic Vision v4.0", "Cetus-Mix v4", "Ghost Mix v2", "ToonYou 6", "None"]

#@markdown Or
MODEL_LINK = "" #@param {type:"string"}
safetensors = True #@param {type:"boolean"}
HF_TOKEN = "" #@param {type:"string"}
user_header = f"\"Authorization: Bearer {HF_TOKEN}\""

if SD_Model == "Dreamshaper v7":
    print("Downloading Dreamshaper v7...")
    # !wget -O /content/VILID/models/Stable-diffusion/Dreamshaper.safetensors https://civitai.com/api/download/models/109123
    print("Stable Diffusion Model Downloaded")
if SD_Model == "ReV Animated v1.2.2":
      print("Downloading ReV Animated v1.2.2...")
      # !wget -O /content/VILID/models/Stable-diffusion/RevAnimated.safetensors https://civitai.com/api/download/models/46846?type=Model&format=SafeTensor&size=full&fp=fp32
      print("Stable Diffusion Model Downloaded")
elif SD_Model == "Protogen x5.8 Rebuilt (Scifi+Anime) Official Release":
      print("Downloading Protogen x5.8 Rebuilt (Scifi+Anime) Official Release...")
      # !wget -O /content/VILID/models/Stable-diffusion/Protogen.safetensors https://civitai.com/api/download/models/4298?type=Model&format=SafeTensor&size=full&fp=fp16
      print("Stable Diffusion Model Downloaded")
elif SD_Model == "Realistic Vision v4.0":
      print("Downloading Realistic Vision v4.0...")
      # !wget -O /content/VILID/models/Stable-diffusion/Realistic-Vision-v4.0.safetensors https://civitai.com/api/download/models/114367?type=Model&format=SafeTensor&size=full&fp=fp16
      print("Stable Diffusion Model Downloaded")
elif SD_Model == "Cetus-Mix v4":
      print("Downloading Cetus-Mix v4...")
      # !wget -O /content/VILID/models/Stable-diffusion/Cetus-Mix.safetensors https://civitai.com/api/download/models/78676?type=Model&format=SafeTensor&size=pruned&fp=fp16
      print("Stable Diffusion Model Downloaded")
elif SD_Model == "Ghost Mix v2":
      print("Downloading Ghost Mix v2...")
      # !wget -O /content/VILID/models/Stable-diffusion/Ghost-Mix.safetensors https://civitai.com/api/download/models/76907?type=Model&format=SafeTensor&size=pruned&fp=fp16
      print("Stable Diffusion Model Downloaded")
elif SD_Model == "ToonYou 6":
      print("Downloading ToonYou 6...")
      # !wget -O /content/VILID/models/Stable-diffusion/ToonYou.safetensors https://civitai.com/api/download/models/125771?type=Model&format=SafeTensor&size=pruned&fp=fp16
      print("Stable Diffusion Model Downloaded")
elif SD_Model == "None":
     print("downloading" +MODEL_LINK +"...")
     # %cd /content/VILID/models/Stable-diffusion
     if not safetensors:
      modelname="model.ckpt"
      # !wget -O $modelname "$MODEL_LINK"
     else:
        modelname="model.safetensors"
        # !wget -O $modelname "$MODEL_LINK"
        print("Stable Diffusion Model Downloaded")
else:
  print("Select Model or Input Model Link")

# VAE & UNET Models
# %cd /content
print("Downloading VAE")
# !wget -O /content/VILID/models/VAE/vae-ft-mse-840000-ema-pruned.ckpt https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt
# !wget -O /content/VILID/models/VAE/kl-f8-anime.ckpt https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt
# !wget -O /content/VILID/models/VAE/raw-vae.ckpt https://civitai.com/api/download/models/94036?type=Model&format=PickleTensor
print("Stable Diffusion VAE Models Downloaded")
print("Downloading UNET")
# !mkdir /content/VILID/models/unet
# !wget -O /content/VILID/models/unet/config.json https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/fp16/unet/config.json
# !wget -O /content/VILID/models/unet/diffusion_pytorch_model.bin https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/fp16/unet/diffusion_pytorch_model.bin
print("Stable Diffusion UNET Models Downloaded")

# Lora, Animation & Roop Models
print("Downloading Lora")
# !mkdir /content/VILID/models/Lora
# !mkdir /content/VILID/models/roop
# !wget -O /content/VILID/models/Lora/lora.zip https://huggingface.co/raannakasturi/VILID-assets/resolve/main/Lora.zip
# %cd /content/VILID/models/Lora
# !unzip /content/VILID/models/Lora/lora.zip
# !rm /content/VILID/models/Lora/lora.zip
print("Stable Diffusion Lora Models Downloaded")
print("Downloading Roop")
# !wget -O /content/VILID/models/roop/inswapper_128.onnx https://huggingface.co/henryruhs/roop/resolve/main/inswapper_128.onnx
print("Stable Diffusion Roop Model Downloaded")
# %cd /content

# Textual Embeddings
# %cd /content/VILID
# !wget -O /content/VILID/embeddings.zip https://huggingface.co/raannakasturi/VILID/resolve/main/embeddings.zip
# %cd /content/VILID/embeddings
# !unzip /content/VILID/embeddings.zip
# !rm /content/VILID/embeddings.zip
# %cd /content
print("Stable Diffusion Textual Embeddings Model Downloaded")

# ControlNet Models
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11e_sd15_ip2p_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11e_sd15_shuffle_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_canny_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11f1p_sd15_depth_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_inpaint_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_lineart_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_mlsd_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_normalbae_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_openpose_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_scribble_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_seg_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_softedge_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15s2_lineart_anime_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11f1e_sd15_tile_fp16.safetensors
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11e_sd15_ip2p_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11e_sd15_shuffle_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_canny_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1p_sd15_depth_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11f1p_sd15_depth_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_inpaint_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_lineart_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_mlsd_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_normalbae_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_openpose_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_scribble_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_seg_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_seg_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15_softedge_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11p_sd15s2_lineart_anime_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1e_sd15_tile_fp16.yaml -Lo /content/VILID/extensions/VILID-controlnet/models/control_v11f1e_sd15_tile_fp16.yaml
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_style_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_style_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_sketch_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_seg_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_seg_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_openpose_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_openpose_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_keypose_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_keypose_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_depth_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_color_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_color_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd14v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_canny_sd14v1.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd15v2.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_canny_sd15v2.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd15v2.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_depth_sd15v2.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd15v2.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_sketch_sd15v2.pth
# !curl https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_zoedepth_sd15v1.pth -Lo /content/VILID/extensions/VILID-controlnet/models/t2iadapter_zoedepth_sd15v1.pth
print("Stable Diffusion ControlNet Models Downloaded")

#@title ESRGAN Models
# %cd /content/VILID/models
# !git clone https://huggingface.co/nolanaatama/ESRGAN
print("Stable Diffusion ESRGAN Model Downloaded")

# %%
#@title Launch
# %cd /content/VILID
# !git reset --hard
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --api --reinstall-xformers --xformers --theme dark --enable-insecure-extension --gradio-queue" REQS_FILE="requirements.txt" python launch.py

# %%
#@title If errors encountered in Launch. Run This Cell.
# %cd /content/VILID
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --api --reinstall-xformers --xformers --theme dark --enable-insecure-extension --gradio-queue" REQS_FILE="requirements_versions.txt" python launch.py
